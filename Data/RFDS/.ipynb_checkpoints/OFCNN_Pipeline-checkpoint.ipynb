# %%
import cv2
import pandas as pd
import os
# https://github.com/AdrianNunez/Fall-Detection-with-CNNs-and-Optical-Flow

# Define directories and CSV file
fall_dir = "originals/fall"
root_output_dir = "OFCNN"
csv_file = "Labels.csv"

# Load the fall event data
fall_data = pd.read_csv(csv_file)
print(fall_data)
# Out:
#      Clip Fall Start Fall End
# 0       1      46.65    49.15
# 1       2       11.9     14.2
# 2       3       2.65        5
# 3       4        0.4      1.4
# 4       5        0.9     3.15
# ..    ...        ...      ...
# 115   116      START      2.1
# 116   117      START      END
# 117   118       1.15        2
# 118   119          1        2
# 119   120        2.9      END
#
# [120 rows x 3 columns]

# %%
def calculate_optical_flow(prvs_frame, next_frame):
    """Calculates and returns the optical flow between two frames."""
    flow = cv2.calcOpticalFlowFarneback(
        prvs_frame, next_frame, None, 0.5, 3, 15, 3, 5, 1.2, 0
    )
    # Convert the flow to HSV to create a color representation
    mag, ang = cv2.cartToPolar(flow[..., 0], flow[..., 1])
    hsv = np.zeros_like(cv2.cvtColor(prvs_frame, cv2.COLOR_GRAY2BGR))
    hsv[..., 1] = 255
    hsv[..., 0] = ang * 180 / np.pi / 2
    hsv[..., 2] = cv2.normalize(mag, None, 0, 255, cv2.NORM_MINMAX)
    optical_flow_image = cv2.cvtColor(hsv, cv2.COLOR_HSV2BGR)
    return optical_flow_image

# %%
import cv2
import pandas as pd
import os
import numpy as np
#Investige 13,26,27,37

# Create directories if they don't exist
os.makedirs(output_dir, exist_ok=True)

# Define processing parameters
clip_durations = [1.0, 2.0]  # clip lengths in seconds
slide_interval = 0.5  # sliding window in seconds

# Process each video in the fall directory
for video_file in os.listdir(fall_dir):
    if video_file.endswith(".mp4"):
        # Extract the clip number from the filename
        clip_number = int(video_file.split('_')[1])

        # Retrieve fall timing for this clip
        fall_row = fall_data[fall_data['Clip'] == clip_number]

        fall_start = fall_row.iloc[0, 1]
        fall_end = fall_row.iloc[0, 2]

        # Handle "START" and "END" values
        if fall_start == "START":
            fall_start = 0.0
        else:
            fall_start = float(fall_start)

        video_path = os.path.join(fall_dir, video_file)
        cap = cv2.VideoCapture(video_path)
        """
        Majority of clips are natively 25 fps a few are lower 13,26,27,37.
        Fixing the fps for a consistent stack of frames for learning.
        """
        fps = 25 
        total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        video_duration = total_frames / fps

        if fall_end == "END":
            fall_end = float(video_duration)
        else:
            fall_end = float(fall_end)

        # Iterate over each clip duration
        for duration in clip_durations:
            # Reopen the video to reset position for each duration
            cap = cv2.VideoCapture(video_path)
            frame_count = int(duration * fps)  # frames per clip
            slide_frames = int(slide_interval * fps)

            clip_index = 0  # counter for clips
            start_frame = 0  # initial start frame

            while start_frame + frame_count <= total_frames:
                # Check if the clip contains a fall
                clip_start_time = float(start_frame / fps)
                clip_end_time = float((start_frame + frame_count) / fps)
                has_fall = not (clip_end_time <= fall_start or clip_start_time >= fall_end)
                label = "FALL" if has_fall else "NO"
                clip_dir = os.path.join(output_dir, str(duration))
                clip_dir = os.path.join(clip_dir, f"{clip_number:03}_{clip_index}_{label}")
                os.makedirs(clip_dir, exist_ok=True)

                # Initialize variables for optical flow
                cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
                ret, first_frame = cap.read()
                if not ret:
                    break
                
                # Write out first frame
                prvs_gray = cv2.cvtColor(first_frame, cv2.COLOR_BGR2GRAY)
                frame_img_name = f"frame_{clip_index:03}_0.png"
                cv2.imwrite(os.path.join(clip_dir, frame_img_name), first_frame)

                # Process remaining frames
                for i in range(1, frame_count):
                    ret, next_frame = cap.read()
                    if not ret:
                        break

                    # Save the current frame
                    frame_img_name = f"frame_{clip_index:03}_{i}.png"
                    cv2.imwrite(os.path.join(clip_dir, frame_img_name), next_frame)

                    # Convert the current frame to grayscale for optical flow
                    next_gray = cv2.cvtColor(next_frame, cv2.COLOR_BGR2GRAY)

                    # Calculate optical flow image
                    optical_flow_image = calculate_optical_flow(prvs_gray, next_gray)
                    
                    # Save the optical flow image
                    flow_img_name = f"flow_{clip_index:03}_{i}.png"
                    cv2.imwrite(os.path.join(clip_dir, flow_img_name), optical_flow_image)

                    # Update previous frame
                    prvs_gray = next_gray

                print(f"Saved frames and optical flow images for clip: {clip_number:03}_{clip_index}")

                # Update frame index for sliding window
                start_frame += slide_frames
                clip_index += 1

            cap.release()
# Out:
# Saved frames and optical flow images for clip: 002_0
# Saved frames and optical flow images for clip: 002_1
# Saved frames and optical flow images for clip: 002_2
# Saved frames and optical flow images for clip: 002_3
# Saved frames and optical flow images for clip: 002_4
# Saved frames and optical flow images for clip: 002_5
# Saved frames and optical flow images for clip: 002_6
# Saved frames and optical flow images for clip: 002_7
# Saved frames and optical flow images for clip: 002_8
# Saved frames and optical flow images for clip: 002_9
# Saved frames and optical flow images for clip: 002_10
# Saved frames and optical flow images for clip: 002_11
# Saved frames and optical flow images for clip: 002_12
# Saved frames and optical flow images for clip: 002_13
# Saved frames and optical flow images for clip: 002_14
# Saved frames and optical flow images for clip: 002_15
# Saved frames and optical flow images for clip: 002_16
# Saved frames and optical flow images for clip: 002_17
# Saved frames and optical flow images for clip: 002_18
# Saved frames and optical flow images for clip: 002_19
# Saved frames and optical flow images for clip: 002_20
# Saved frames and optical flow images for clip: 002_21
# Saved frames and optical flow images for clip: 002_22
# Saved frames and optical flow images for clip: 002_23
# Saved frames and optical flow images for clip: 002_24
# Saved frames and optical flow images for clip: 002_25
# Saved frames and optical flow images for clip: 002_26
# Saved frames and optical flow images for clip: 002_27
# Saved frames and optical flow images for clip: 002_28
# Saved frames and optical flow images for clip: 002_29
# Saved frames and optical flow images for clip: 002_0
# Saved frames and optical flow images for clip: 002_1
# Saved frames and optical flow images for clip: 002_2
# Saved frames and optical flow images for clip: 002_3
# Saved frames and optical flow images for clip: 002_4
# Saved frames and optical flow images for clip: 002_5
# Saved frames and optical flow images for clip: 002_6
# Saved frames and optical flow images for clip: 002_7
# Saved frames and optical flow images for clip: 002_8
# Saved frames and optical flow images for clip: 002_9
# Saved frames and optical flow images for clip: 002_10
# Saved frames and optical flow images for clip: 002_11
# Saved frames and optical flow images for clip: 002_12
# Saved frames and optical flow images for clip: 002_13
# Saved frames and optical flow images for clip: 002_14
# Saved frames and optical flow images for clip: 002_15
# Saved frames and optical flow images for clip: 002_16
# Saved frames and optical flow images for clip: 002_17
# Saved frames and optical flow images for clip: 002_18
# Saved frames and optical flow images for clip: 002_19
# Saved frames and optical flow images for clip: 002_20
# Saved frames and optical flow images for clip: 002_21
# Saved frames and optical flow images for clip: 002_22
# Saved frames and optical flow images for clip: 002_23
# Saved frames and optical flow images for clip: 002_24
# Saved frames and optical flow images for clip: 002_25
# Saved frames and optical flow images for clip: 002_26
# Saved frames and optical flow images for clip: 002_27
# Saved frames and optical flow images for clip: 006_0
# Saved frames and optical flow images for clip: 006_1
# Saved frames and optical flow images for clip: 006_2
# Saved frames and optical flow images for clip: 006_3
# Saved frames and optical flow images for clip: 006_4
# Saved frames and optical flow images for clip: 006_5
# Saved frames and optical flow images for clip: 006_6
# Saved frames and optical flow images for clip: 006_7
# Saved frames and optical flow images for clip: 006_8
# Saved frames and optical flow images for clip: 006_9
# Saved frames and optical flow images for clip: 006_10
# Saved frames and optical flow images for clip: 006_11
# Saved frames and optical flow images for clip: 006_12
# Saved frames and optical flow images for clip: 006_13
# Saved frames and optical flow images for clip: 006_14
# Saved frames and optical flow images for clip: 006_0
# Saved frames and optical flow images for clip: 006_1
# Saved frames and optical flow images for clip: 006_2
# Saved frames and optical flow images for clip: 006_3
# Saved frames and optical flow images for clip: 006_4
# Saved frames and optical flow images for clip: 006_5
# Saved frames and optical flow images for clip: 006_6
# Saved frames and optical flow images for clip: 006_7
# Saved frames and optical flow images for clip: 006_8
# Saved frames and optical flow images for clip: 006_9
# Saved frames and optical flow images for clip: 006_10
# Saved frames and optical flow images for clip: 006_11
# Saved frames and optical flow images for clip: 006_12
# Saved frames and optical flow images for clip: 003_0
# Saved frames and optical flow images for clip: 003_1
# Saved frames and optical flow images for clip: 003_2
# Saved frames and optical flow images for clip: 003_3
# Saved frames and optical flow images for clip: 003_4
# Saved frames and optical flow images for clip: 003_5
# Saved frames and optical flow images for clip: 003_6
# Saved frames and optical flow images for clip: 003_7
# Saved frames and optical flow images for clip: 003_8
# Saved frames and optical flow images for clip: 003_9
# Saved frames and optical flow images for clip: 003_10
# Saved frames and optical flow images for clip: 003_0
# Saved frames and optical flow images for clip: 003_1
# Saved frames and optical flow images for clip: 003_2
# Saved frames and optical flow images for clip: 003_3
# Saved frames and optical flow images for clip: 003_4
# Saved frames and optical flow images for clip: 003_5
# Saved frames and optical flow images for clip: 003_6
# Saved frames and optical flow images for clip: 003_7
# Saved frames and optical flow images for clip: 003_8
# Saved frames and optical flow images for clip: 114_0
# Saved frames and optical flow images for clip: 114_1
# Saved frames and optical flow images for clip: 114_2
# Saved frames and optical flow images for clip: 114_3
# Saved frames and optical flow images for clip: 114_4
# Saved frames and optical flow images for clip: 114_5
# Saved frames and optical flow images for clip: 114_6
# Saved frames and optical flow images for clip: 114_7
# Saved frames and optical flow images for clip: 114_8
# Saved frames and optical flow images for clip: 114_9
# Saved frames and optical flow images for clip: 114_10
# Saved frames and optical flow images for clip: 114_11
# Saved frames and optical flow images for clip: 114_12
# Saved frames and optical flow images for clip: 114_13
# Saved frames and optical flow images for clip: 114_14
# Saved frames and optical flow images for clip: 114_15
# Saved frames and optical flow images for clip: 114_16
# Saved frames and optical flow images for clip: 114_0
# Saved frames and optical flow images for clip: 114_1
# Saved frames and optical flow images for clip: 114_2
# Saved frames and optical flow images for clip: 114_3
# Saved frames and optical flow images for clip: 114_4
# Saved frames and optical flow images for clip: 114_5
# Saved frames and optical flow images for clip: 114_6
# Saved frames and optical flow images for clip: 114_7
# Saved frames and optical flow images for clip: 114_8
# Saved frames and optical flow images for clip: 114_9
# Saved frames and optical flow images for clip: 114_10
# Saved frames and optical flow images for clip: 114_11
# Saved frames and optical flow images for clip: 114_12
# Saved frames and optical flow images for clip: 114_13
# Saved frames and optical flow images for clip: 114_14
# Saved frames and optical flow images for clip: 050_0
# Saved frames and optical flow images for clip: 050_1
# Saved frames and optical flow images for clip: 050_2
# Saved frames and optical flow images for clip: 050_3
# Saved frames and optical flow images for clip: 050_4
# Saved frames and optical flow images for clip: 050_5
# Saved frames and optical flow images for clip: 050_6
# Saved frames and optical flow images for clip: 050_7
# Saved frames and optical flow images for clip: 050_8
# Saved frames and optical flow images for clip: 050_0
# Saved frames and optical flow images for clip: 050_1
# Saved frames and optical flow images for clip: 050_2
# Saved frames and optical flow images for clip: 050_3
# Saved frames and optical flow images for clip: 050_4
# Saved frames and optical flow images for clip: 050_5
# Saved frames and optical flow images for clip: 050_6
# Saved frames and optical flow images for clip: 004_0
# Saved frames and optical flow images for clip: 004_1
# Saved frames and optical flow images for clip: 004_2
# Saved frames and optical flow images for clip: 004_3
# Saved frames and optical flow images for clip: 004_4
# Saved frames and optical flow images for clip: 004_5
# Saved frames and optical flow images for clip: 004_6
# Saved frames and optical flow images for clip: 004_7
# Saved frames and optical flow images for clip: 004_8
# Saved frames and optical flow images for clip: 004_9
# Saved frames and optical flow images for clip: 004_10
# Saved frames and optical flow images for clip: 004_11
# Saved frames and optical flow images for clip: 004_12
# Saved frames and optical flow images for clip: 004_13
# Saved frames and optical flow images for clip: 004_14
# Saved frames and optical flow images for clip: 004_15
# Saved frames and optical flow images for clip: 004_16
# Saved frames and optical flow images for clip: 004_17
# Saved frames and optical flow images for clip: 004_18
# Saved frames and optical flow images for clip: 004_19
# Saved frames and optical flow images for clip: 004_20
# Saved frames and optical flow images for clip: 004_0
# Saved frames and optical flow images for clip: 004_1
# Saved frames and optical flow images for clip: 004_2
# Saved frames and optical flow images for clip: 004_3
# Saved frames and optical flow images for clip: 004_4
# Saved frames and optical flow images for clip: 004_5
# Saved frames and optical flow images for clip: 004_6
# Saved frames and optical flow images for clip: 004_7
# Saved frames and optical flow images for clip: 004_8
# Saved frames and optical flow images for clip: 004_9
# Saved frames and optical flow images for clip: 004_10
# Saved frames and optical flow images for clip: 004_11
# Saved frames and optical flow images for clip: 004_12
# Saved frames and optical flow images for clip: 004_13
# Saved frames and optical flow images for clip: 004_14
# Saved frames and optical flow images for clip: 004_15
# Saved frames and optical flow images for clip: 004_16
# Saved frames and optical flow images for clip: 004_17
# Saved frames and optical flow images for clip: 004_18
# Saved frames and optical flow images for clip: 111_0
# Saved frames and optical flow images for clip: 111_1
# Saved frames and optical flow images for clip: 111_2
# Saved frames and optical flow images for clip: 111_3
# Saved frames and optical flow images for clip: 111_4
# Saved frames and optical flow images for clip: 111_0
# Saved frames and optical flow images for clip: 111_1
# Saved frames and optical flow images for clip: 111_2
# Saved frames and optical flow images for clip: 017_0
# Saved frames and optical flow images for clip: 017_1
# Saved frames and optical flow images for clip: 017_2
# Saved frames and optical flow images for clip: 017_3
# Saved frames and optical flow images for clip: 017_4
# Saved frames and optical flow images for clip: 017_5
# Saved frames and optical flow images for clip: 017_6
# Saved frames and optical flow images for clip: 017_7
# Saved frames and optical flow images for clip: 017_0
# Saved frames and optical flow images for clip: 017_1
# Saved frames and optical flow images for clip: 017_2
# Saved frames and optical flow images for clip: 017_3
# Saved frames and optical flow images for clip: 017_4
# Saved frames and optical flow images for clip: 017_5
# Saved frames and optical flow images for clip: 107_0
# Saved frames and optical flow images for clip: 107_1
# Saved frames and optical flow images for clip: 107_2
# Saved frames and optical flow images for clip: 107_3
# Saved frames and optical flow images for clip: 107_4
# Saved frames and optical flow images for clip: 107_0
# Saved frames and optical flow images for clip: 107_1
# Saved frames and optical flow images for clip: 107_2
# Saved frames and optical flow images for clip: 117_0
# Saved frames and optical flow images for clip: 117_1
# Saved frames and optical flow images for clip: 011_0
# Saved frames and optical flow images for clip: 011_1
# Saved frames and optical flow images for clip: 011_2
# Saved frames and optical flow images for clip: 011_3
# Saved frames and optical flow images for clip: 011_4
# Saved frames and optical flow images for clip: 011_5
# Saved frames and optical flow images for clip: 011_6
# Saved frames and optical flow images for clip: 011_7
# Saved frames and optical flow images for clip: 011_8
# Saved frames and optical flow images for clip: 011_9
# Saved frames and optical flow images for clip: 011_10
# Saved frames and optical flow images for clip: 011_11
# Saved frames and optical flow images for clip: 011_12
# Saved frames and optical flow images for clip: 011_13
# Saved frames and optical flow images for clip: 011_14
# Saved frames and optical flow images for clip: 011_15
# Saved frames and optical flow images for clip: 011_16
# Saved frames and optical flow images for clip: 011_17
# Saved frames and optical flow images for clip: 011_18
# Saved frames and optical flow images for clip: 011_19
# Saved frames and optical flow images for clip: 011_20
# Saved frames and optical flow images for clip: 011_21
# Saved frames and optical flow images for clip: 011_22
# Saved frames and optical flow images for clip: 011_23
# Saved frames and optical flow images for clip: 011_24
# Saved frames and optical flow images for clip: 011_25
# Saved frames and optical flow images for clip: 011_26
# Saved frames and optical flow images for clip: 011_27
# Saved frames and optical flow images for clip: 011_28
# Saved frames and optical flow images for clip: 011_29
# Saved frames and optical flow images for clip: 011_0
# Saved frames and optical flow images for clip: 011_1
# Saved frames and optical flow images for clip: 011_2
# Saved frames and optical flow images for clip: 011_3
# Saved frames and optical flow images for clip: 011_4
# Saved frames and optical flow images for clip: 011_5
# Saved frames and optical flow images for clip: 011_6
# Saved frames and optical flow images for clip: 011_7
# Saved frames and optical flow images for clip: 011_8
# Saved frames and optical flow images for clip: 011_9
# Saved frames and optical flow images for clip: 011_10
# Saved frames and optical flow images for clip: 011_11
# Saved frames and optical flow images for clip: 011_12
# Saved frames and optical flow images for clip: 011_13
# Saved frames and optical flow images for clip: 011_14
# Saved frames and optical flow images for clip: 011_15
# Saved frames and optical flow images for clip: 011_16
# Saved frames and optical flow images for clip: 011_17
# Saved frames and optical flow images for clip: 011_18
# Saved frames and optical flow images for clip: 011_19
# Saved frames and optical flow images for clip: 011_20
# Saved frames and optical flow images for clip: 011_21
# Saved frames and optical flow images for clip: 011_22
# Saved frames and optical flow images for clip: 011_23
# Saved frames and optical flow images for clip: 011_24
# Saved frames and optical flow images for clip: 011_25
# Saved frames and optical flow images for clip: 011_26
# Saved frames and optical flow images for clip: 011_27
# Saved frames and optical flow images for clip: 119_0
# Saved frames and optical flow images for clip: 119_1
# Saved frames and optical flow images for clip: 119_2
# Saved frames and optical flow images for clip: 119_3
# Saved frames and optical flow images for clip: 119_4
# Saved frames and optical flow images for clip: 119_5
# Saved frames and optical flow images for clip: 119_6
# Saved frames and optical flow images for clip: 119_7
# Saved frames and optical flow images for clip: 119_8
# Saved frames and optical flow images for clip: 119_9
# Saved frames and optical flow images for clip: 119_10
# Saved frames and optical flow images for clip: 119_11
# Saved frames and optical flow images for clip: 119_0
# Saved frames and optical flow images for clip: 119_1
# Saved frames and optical flow images for clip: 119_2
# Saved frames and optical flow images for clip: 119_3
# Saved frames and optical flow images for clip: 119_4
# Saved frames and optical flow images for clip: 119_5
# Saved frames and optical flow images for clip: 119_6
# Saved frames and optical flow images for clip: 119_7
# Saved frames and optical flow images for clip: 119_8
# Saved frames and optical flow images for clip: 119_9
# Saved frames and optical flow images for clip: 015_0
# Saved frames and optical flow images for clip: 015_1
# Saved frames and optical flow images for clip: 015_2
# Saved frames and optical flow images for clip: 015_3
# Saved frames and optical flow images for clip: 015_4
# Saved frames and optical flow images for clip: 015_5
# Saved frames and optical flow images for clip: 015_6
# Saved frames and optical flow images for clip: 015_7
# Saved frames and optical flow images for clip: 015_8
# Saved frames and optical flow images for clip: 015_9
# Saved frames and optical flow images for clip: 015_10
# Saved frames and optical flow images for clip: 015_11
# Saved frames and optical flow images for clip: 015_12
# Saved frames and optical flow images for clip: 015_13
# Saved frames and optical flow images for clip: 015_14
# Saved frames and optical flow images for clip: 015_15
# Saved frames and optical flow images for clip: 015_16
# Saved frames and optical flow images for clip: 015_17
# Saved frames and optical flow images for clip: 015_18
# Saved frames and optical flow images for clip: 015_19
# Saved frames and optical flow images for clip: 015_20
# Saved frames and optical flow images for clip: 015_0
# Saved frames and optical flow images for clip: 015_1
# Saved frames and optical flow images for clip: 015_2
# Saved frames and optical flow images for clip: 015_3
# Saved frames and optical flow images for clip: 015_4
# Saved frames and optical flow images for clip: 015_5
# Saved frames and optical flow images for clip: 015_6
# Saved frames and optical flow images for clip: 015_7
# Saved frames and optical flow images for clip: 015_8
# Saved frames and optical flow images for clip: 015_9
# Saved frames and optical flow images for clip: 015_10
# Saved frames and optical flow images for clip: 015_11
# Saved frames and optical flow images for clip: 015_12
# Saved frames and optical flow images for clip: 015_13
# Saved frames and optical flow images for clip: 015_14
# Saved frames and optical flow images for clip: 015_15
# Saved frames and optical flow images for clip: 015_16
# Saved frames and optical flow images for clip: 015_17
# Saved frames and optical flow images for clip: 015_18
# Saved frames and optical flow images for clip: 091_0
# Saved frames and optical flow images for clip: 091_1
# Saved frames and optical flow images for clip: 091_2
# Saved frames and optical flow images for clip: 091_3
# Saved frames and optical flow images for clip: 091_4
# Saved frames and optical flow images for clip: 091_5
# Saved frames and optical flow images for clip: 091_6
# Saved frames and optical flow images for clip: 091_0
# Saved frames and optical flow images for clip: 091_1
# Saved frames and optical flow images for clip: 091_2
# Saved frames and optical flow images for clip: 091_3
# Saved frames and optical flow images for clip: 091_4
# Saved frames and optical flow images for clip: 092_0
# Saved frames and optical flow images for clip: 092_1
# Saved frames and optical flow images for clip: 092_2
# Saved frames and optical flow images for clip: 092_3
# Saved frames and optical flow images for clip: 092_4
# Saved frames and optical flow images for clip: 092_5
# Saved frames and optical flow images for clip: 092_6
# Saved frames and optical flow images for clip: 092_7
# Saved frames and optical flow images for clip: 092_8
# Saved frames and optical flow images for clip: 092_9
# Saved frames and optical flow images for clip: 092_10
# Saved frames and optical flow images for clip: 092_11
# Saved frames and optical flow images for clip: 092_0
# Saved frames and optical flow images for clip: 092_1
# Saved frames and optical flow images for clip: 092_2
# Saved frames and optical flow images for clip: 092_3
# Saved frames and optical flow images for clip: 092_4
# Saved frames and optical flow images for clip: 092_5
# Saved frames and optical flow images for clip: 092_6
# Saved frames and optical flow images for clip: 092_7
# Saved frames and optical flow images for clip: 092_8
# Saved frames and optical flow images for clip: 092_9
# Saved frames and optical flow images for clip: 037_0
# Saved frames and optical flow images for clip: 037_1
# Saved frames and optical flow images for clip: 037_2
# Saved frames and optical flow images for clip: 037_3
# Saved frames and optical flow images for clip: 037_4
# Saved frames and optical flow images for clip: 037_5
# Saved frames and optical flow images for clip: 037_6
# Saved frames and optical flow images for clip: 037_7
# Saved frames and optical flow images for clip: 037_0
# Saved frames and optical flow images for clip: 037_1
# Saved frames and optical flow images for clip: 037_2
# Saved frames and optical flow images for clip: 037_3
# Saved frames and optical flow images for clip: 037_4
# Saved frames and optical flow images for clip: 037_5
# Saved frames and optical flow images for clip: 018_0
# Saved frames and optical flow images for clip: 018_1
# Saved frames and optical flow images for clip: 018_2
# Saved frames and optical flow images for clip: 018_3
# Saved frames and optical flow images for clip: 018_4
# Saved frames and optical flow images for clip: 018_5
# Saved frames and optical flow images for clip: 018_6
# Saved frames and optical flow images for clip: 018_7
# Saved frames and optical flow images for clip: 018_8
# Saved frames and optical flow images for clip: 018_9
# Saved frames and optical flow images for clip: 018_10
# Saved frames and optical flow images for clip: 018_11
# Saved frames and optical flow images for clip: 018_12
# Saved frames and optical flow images for clip: 018_13
# Saved frames and optical flow images for clip: 018_14
# Saved frames and optical flow images for clip: 018_15
# Saved frames and optical flow images for clip: 018_16
# Saved frames and optical flow images for clip: 018_17
# Saved frames and optical flow images for clip: 018_18
# Saved frames and optical flow images for clip: 018_19
# Saved frames and optical flow images for clip: 018_20
# Saved frames and optical flow images for clip: 018_21
# Saved frames and optical flow images for clip: 018_22
# Saved frames and optical flow images for clip: 018_0
# Saved frames and optical flow images for clip: 018_1
# Saved frames and optical flow images for clip: 018_2
# Saved frames and optical flow images for clip: 018_3
# Saved frames and optical flow images for clip: 018_4
# Saved frames and optical flow images for clip: 018_5
# Saved frames and optical flow images for clip: 018_6
# Saved frames and optical flow images for clip: 018_7
# Saved frames and optical flow images for clip: 018_8
# Saved frames and optical flow images for clip: 018_9
# Saved frames and optical flow images for clip: 018_10
# Saved frames and optical flow images for clip: 018_11
# Saved frames and optical flow images for clip: 018_12
# Saved frames and optical flow images for clip: 018_13
# Saved frames and optical flow images for clip: 018_14
# Saved frames and optical flow images for clip: 018_15
# Saved frames and optical flow images for clip: 018_16
# Saved frames and optical flow images for clip: 018_17
# Saved frames and optical flow images for clip: 018_18
# Saved frames and optical flow images for clip: 018_19
# Saved frames and optical flow images for clip: 018_20
# Saved frames and optical flow images for clip: 008_0
# Saved frames and optical flow images for clip: 008_1
# Saved frames and optical flow images for clip: 008_2
# Saved frames and optical flow images for clip: 008_3
# Saved frames and optical flow images for clip: 008_4
# Saved frames and optical flow images for clip: 008_5
# Saved frames and optical flow images for clip: 008_6
# Saved frames and optical flow images for clip: 008_7
# Saved frames and optical flow images for clip: 008_8
# Saved frames and optical flow images for clip: 008_9
# Saved frames and optical flow images for clip: 008_10
# Saved frames and optical flow images for clip: 008_0
# Saved frames and optical flow images for clip: 008_1
# Saved frames and optical flow images for clip: 008_2
# Saved frames and optical flow images for clip: 008_3
# Saved frames and optical flow images for clip: 008_4
# Saved frames and optical flow images for clip: 008_5
# Saved frames and optical flow images for clip: 008_6
# Saved frames and optical flow images for clip: 008_7
# Saved frames and optical flow images for clip: 008_8
# Saved frames and optical flow images for clip: 029_0
# Saved frames and optical flow images for clip: 029_1
# Saved frames and optical flow images for clip: 029_2
# Saved frames and optical flow images for clip: 029_3
# Saved frames and optical flow images for clip: 029_4
# Saved frames and optical flow images for clip: 029_5
# Saved frames and optical flow images for clip: 029_6
# Saved frames and optical flow images for clip: 029_7
# Saved frames and optical flow images for clip: 029_8
# Saved frames and optical flow images for clip: 029_9
# Saved frames and optical flow images for clip: 029_10
# Saved frames and optical flow images for clip: 029_11
# Saved frames and optical flow images for clip: 029_12
# Saved frames and optical flow images for clip: 029_13
# Saved frames and optical flow images for clip: 029_14
# Saved frames and optical flow images for clip: 029_15
# Saved frames and optical flow images for clip: 029_16
# Saved frames and optical flow images for clip: 029_17
# Saved frames and optical flow images for clip: 029_18
# Saved frames and optical flow images for clip: 029_19
# Saved frames and optical flow images for clip: 029_20
# Saved frames and optical flow images for clip: 029_0
# Saved frames and optical flow images for clip: 029_1
# Saved frames and optical flow images for clip: 029_2
# Saved frames and optical flow images for clip: 029_3
# Saved frames and optical flow images for clip: 029_4
# Saved frames and optical flow images for clip: 029_5
# Saved frames and optical flow images for clip: 029_6
# Saved frames and optical flow images for clip: 029_7
# Saved frames and optical flow images for clip: 029_8
# Saved frames and optical flow images for clip: 029_9
# Saved frames and optical flow images for clip: 029_10
# Saved frames and optical flow images for clip: 029_11
# Saved frames and optical flow images for clip: 029_12
# Saved frames and optical flow images for clip: 029_13
# Saved frames and optical flow images for clip: 029_14
# Saved frames and optical flow images for clip: 029_15
# Saved frames and optical flow images for clip: 029_16
# Saved frames and optical flow images for clip: 029_17
# Saved frames and optical flow images for clip: 029_18
# Saved frames and optical flow images for clip: 090_0
# Saved frames and optical flow images for clip: 090_1
# Saved frames and optical flow images for clip: 090_2
# Saved frames and optical flow images for clip: 090_3
# Saved frames and optical flow images for clip: 090_4
# Saved frames and optical flow images for clip: 090_5
# Saved frames and optical flow images for clip: 090_6
# Saved frames and optical flow images for clip: 090_7
# Saved frames and optical flow images for clip: 090_8
# Saved frames and optical flow images for clip: 090_9
# Saved frames and optical flow images for clip: 090_10
# Saved frames and optical flow images for clip: 090_0
# Saved frames and optical flow images for clip: 090_1
# Saved frames and optical flow images for clip: 090_2
# Saved frames and optical flow images for clip: 090_3
# Saved frames and optical flow images for clip: 090_4
# Saved frames and optical flow images for clip: 090_5
# Saved frames and optical flow images for clip: 090_6
# Saved frames and optical flow images for clip: 090_7
# Saved frames and optical flow images for clip: 090_8
# Saved frames and optical flow images for clip: 034_0
# Saved frames and optical flow images for clip: 034_1
# Saved frames and optical flow images for clip: 034_2
# Saved frames and optical flow images for clip: 034_3
# Saved frames and optical flow images for clip: 034_4
# Saved frames and optical flow images for clip: 034_5
# Saved frames and optical flow images for clip: 034_6
# Saved frames and optical flow images for clip: 034_7
# Saved frames and optical flow images for clip: 034_8
# Saved frames and optical flow images for clip: 034_9
# Saved frames and optical flow images for clip: 034_10
# Saved frames and optical flow images for clip: 034_11
# Saved frames and optical flow images for clip: 034_12
# Saved frames and optical flow images for clip: 034_13
# Saved frames and optical flow images for clip: 034_14
# Saved frames and optical flow images for clip: 034_15
# Saved frames and optical flow images for clip: 034_16
# Saved frames and optical flow images for clip: 034_17
# Saved frames and optical flow images for clip: 034_18
# Saved frames and optical flow images for clip: 034_0
# Saved frames and optical flow images for clip: 034_1
# Saved frames and optical flow images for clip: 034_2
# Saved frames and optical flow images for clip: 034_3
# Saved frames and optical flow images for clip: 034_4
# Saved frames and optical flow images for clip: 034_5
# Saved frames and optical flow images for clip: 034_6
# Saved frames and optical flow images for clip: 034_7
# Saved frames and optical flow images for clip: 034_8
# Saved frames and optical flow images for clip: 034_9
# Saved frames and optical flow images for clip: 034_10
# Saved frames and optical flow images for clip: 034_11
# Saved frames and optical flow images for clip: 034_12
# Saved frames and optical flow images for clip: 034_13
# Saved frames and optical flow images for clip: 034_14
# Saved frames and optical flow images for clip: 034_15
# Saved frames and optical flow images for clip: 034_16
# Saved frames and optical flow images for clip: 116_0
# Saved frames and optical flow images for clip: 116_1
# Saved frames and optical flow images for clip: 116_2
# Saved frames and optical flow images for clip: 116_3
# Saved frames and optical flow images for clip: 116_4
# Saved frames and optical flow images for clip: 116_5
# Saved frames and optical flow images for clip: 116_6
# Saved frames and optical flow images for clip: 116_7
# Saved frames and optical flow images for clip: 116_0
# Saved frames and optical flow images for clip: 116_1
# Saved frames and optical flow images for clip: 116_2
# Saved frames and optical flow images for clip: 116_3
# Saved frames and optical flow images for clip: 116_4
# Saved frames and optical flow images for clip: 116_5
# Saved frames and optical flow images for clip: 113_0
# Saved frames and optical flow images for clip: 113_1
# Saved frames and optical flow images for clip: 113_2
# Saved frames and optical flow images for clip: 113_3
# Saved frames and optical flow images for clip: 113_4
# Saved frames and optical flow images for clip: 113_5
# Saved frames and optical flow images for clip: 113_6
# Saved frames and optical flow images for clip: 113_7
# Saved frames and optical flow images for clip: 113_8
# Saved frames and optical flow images for clip: 113_9
# Saved frames and optical flow images for clip: 113_10
# Saved frames and optical flow images for clip: 113_11
# Saved frames and optical flow images for clip: 113_12
# Saved frames and optical flow images for clip: 113_13
# Saved frames and optical flow images for clip: 113_14
# Saved frames and optical flow images for clip: 113_15
# Saved frames and optical flow images for clip: 113_0
# Saved frames and optical flow images for clip: 113_1
# Saved frames and optical flow images for clip: 113_2
# Saved frames and optical flow images for clip: 113_3
# Saved frames and optical flow images for clip: 113_4
# Saved frames and optical flow images for clip: 113_5
# Saved frames and optical flow images for clip: 113_6
# Saved frames and optical flow images for clip: 113_7
# Saved frames and optical flow images for clip: 113_8
# Saved frames and optical flow images for clip: 113_9
# Saved frames and optical flow images for clip: 113_10
# Saved frames and optical flow images for clip: 113_11
# Saved frames and optical flow images for clip: 113_12
# Saved frames and optical flow images for clip: 045_0
# Saved frames and optical flow images for clip: 045_1
# Saved frames and optical flow images for clip: 045_2
# Saved frames and optical flow images for clip: 045_0
# Saved frames and optical flow images for clip: 010_0
# Saved frames and optical flow images for clip: 010_1
# Saved frames and optical flow images for clip: 010_2
# Saved frames and optical flow images for clip: 010_3
# Saved frames and optical flow images for clip: 010_4
# Saved frames and optical flow images for clip: 010_5
# Saved frames and optical flow images for clip: 010_6
# Saved frames and optical flow images for clip: 010_7
# Saved frames and optical flow images for clip: 010_8
# Saved frames and optical flow images for clip: 010_9
# Saved frames and optical flow images for clip: 010_10
# Saved frames and optical flow images for clip: 010_11
# Saved frames and optical flow images for clip: 010_12
# Saved frames and optical flow images for clip: 010_13
# Saved frames and optical flow images for clip: 010_14
# Saved frames and optical flow images for clip: 010_15
# Saved frames and optical flow images for clip: 010_16
# Saved frames and optical flow images for clip: 010_0
# Saved frames and optical flow images for clip: 010_1
# Saved frames and optical flow images for clip: 010_2
# Saved frames and optical flow images for clip: 010_3
# Saved frames and optical flow images for clip: 010_4
# Saved frames and optical flow images for clip: 010_5
# Saved frames and optical flow images for clip: 010_6
# Saved frames and optical flow images for clip: 010_7
# Saved frames and optical flow images for clip: 010_8
# Saved frames and optical flow images for clip: 010_9
# Saved frames and optical flow images for clip: 010_10
# Saved frames and optical flow images for clip: 010_11
# Saved frames and optical flow images for clip: 010_12
# Saved frames and optical flow images for clip: 010_13
# Saved frames and optical flow images for clip: 010_14
# Saved frames and optical flow images for clip: 048_0
# Saved frames and optical flow images for clip: 048_1
# Saved frames and optical flow images for clip: 048_2
# Saved frames and optical flow images for clip: 048_3
# Saved frames and optical flow images for clip: 048_4
# Saved frames and optical flow images for clip: 048_5
# Saved frames and optical flow images for clip: 048_6
# Saved frames and optical flow images for clip: 048_7
# Saved frames and optical flow images for clip: 048_8
# Saved frames and optical flow images for clip: 048_9
# Saved frames and optical flow images for clip: 048_10
# Saved frames and optical flow images for clip: 048_11
# Saved frames and optical flow images for clip: 048_12
# Saved frames and optical flow images for clip: 048_0
# Saved frames and optical flow images for clip: 048_1
# Saved frames and optical flow images for clip: 048_2
# Saved frames and optical flow images for clip: 048_3
# Saved frames and optical flow images for clip: 048_4
# Saved frames and optical flow images for clip: 048_5
# Saved frames and optical flow images for clip: 048_6
# Saved frames and optical flow images for clip: 048_7
# Saved frames and optical flow images for clip: 048_8
# Saved frames and optical flow images for clip: 048_9
# Saved frames and optical flow images for clip: 048_10
# Saved frames and optical flow images for clip: 081_0
# Saved frames and optical flow images for clip: 081_1
# Saved frames and optical flow images for clip: 081_2
# Saved frames and optical flow images for clip: 081_3
# Saved frames and optical flow images for clip: 081_4
# Saved frames and optical flow images for clip: 081_5
# Saved frames and optical flow images for clip: 081_6
# Saved frames and optical flow images for clip: 081_7
# Saved frames and optical flow images for clip: 081_8
# Saved frames and optical flow images for clip: 081_9
# Saved frames and optical flow images for clip: 081_10
# Saved frames and optical flow images for clip: 081_11
# Saved frames and optical flow images for clip: 081_12
# Saved frames and optical flow images for clip: 081_13
# Saved frames and optical flow images for clip: 081_14
# Saved frames and optical flow images for clip: 081_15
# Saved frames and optical flow images for clip: 081_16
# Saved frames and optical flow images for clip: 081_17
# Saved frames and optical flow images for clip: 081_18
# Saved frames and optical flow images for clip: 081_19
# Saved frames and optical flow images for clip: 081_20
# Saved frames and optical flow images for clip: 081_0
# Saved frames and optical flow images for clip: 081_1
# Saved frames and optical flow images for clip: 081_2
# Saved frames and optical flow images for clip: 081_3
# Saved frames and optical flow images for clip: 081_4
# Saved frames and optical flow images for clip: 081_5
# Saved frames and optical flow images for clip: 081_6
# Saved frames and optical flow images for clip: 081_7
# Saved frames and optical flow images for clip: 081_8
# Saved frames and optical flow images for clip: 081_9
# Saved frames and optical flow images for clip: 081_10
# Saved frames and optical flow images for clip: 081_11
# Saved frames and optical flow images for clip: 081_12
# Saved frames and optical flow images for clip: 081_13
# Saved frames and optical flow images for clip: 081_14
# Saved frames and optical flow images for clip: 081_15
# Saved frames and optical flow images for clip: 081_16
# Saved frames and optical flow images for clip: 081_17
# Saved frames and optical flow images for clip: 081_18
# Saved frames and optical flow images for clip: 022_0
# Saved frames and optical flow images for clip: 022_1
# Saved frames and optical flow images for clip: 022_2
# Saved frames and optical flow images for clip: 022_3
# Saved frames and optical flow images for clip: 022_4
# Saved frames and optical flow images for clip: 022_5
# Saved frames and optical flow images for clip: 022_6
# Saved frames and optical flow images for clip: 022_7
# Saved frames and optical flow images for clip: 022_8
# Saved frames and optical flow images for clip: 022_9
# Saved frames and optical flow images for clip: 022_10
# Saved frames and optical flow images for clip: 022_11
# Saved frames and optical flow images for clip: 022_12
# Saved frames and optical flow images for clip: 022_13
# Saved frames and optical flow images for clip: 022_14
# Saved frames and optical flow images for clip: 022_15
# Saved frames and optical flow images for clip: 022_16
# Saved frames and optical flow images for clip: 022_17
# Saved frames and optical flow images for clip: 022_18
# Saved frames and optical flow images for clip: 022_19
# Saved frames and optical flow images for clip: 022_20
# Saved frames and optical flow images for clip: 022_21
# Saved frames and optical flow images for clip: 022_22
# Saved frames and optical flow images for clip: 022_23
# Saved frames and optical flow images for clip: 022_24
# Saved frames and optical flow images for clip: 022_25
# Saved frames and optical flow images for clip: 022_26
# Saved frames and optical flow images for clip: 022_27
# Saved frames and optical flow images for clip: 022_28
# Saved frames and optical flow images for clip: 022_29
# Saved frames and optical flow images for clip: 022_0
# Saved frames and optical flow images for clip: 022_1
# Saved frames and optical flow images for clip: 022_2
# Saved frames and optical flow images for clip: 022_3
# Saved frames and optical flow images for clip: 022_4
# Saved frames and optical flow images for clip: 022_5
# Saved frames and optical flow images for clip: 022_6
# Saved frames and optical flow images for clip: 022_7
# Saved frames and optical flow images for clip: 022_8
# Saved frames and optical flow images for clip: 022_9
# Saved frames and optical flow images for clip: 022_10
# Saved frames and optical flow images for clip: 022_11
# Saved frames and optical flow images for clip: 022_12
# Saved frames and optical flow images for clip: 022_13
# Saved frames and optical flow images for clip: 022_14
# Saved frames and optical flow images for clip: 022_15
# Saved frames and optical flow images for clip: 022_16
# Saved frames and optical flow images for clip: 022_17
# Saved frames and optical flow images for clip: 022_18
# Saved frames and optical flow images for clip: 022_19
# Saved frames and optical flow images for clip: 022_20
# Saved frames and optical flow images for clip: 022_21
# Saved frames and optical flow images for clip: 022_22
# Saved frames and optical flow images for clip: 022_23
# Saved frames and optical flow images for clip: 022_24
# Saved frames and optical flow images for clip: 022_25
# Saved frames and optical flow images for clip: 022_26
# Saved frames and optical flow images for clip: 022_27
# Saved frames and optical flow images for clip: 053_0
# Saved frames and optical flow images for clip: 053_1
# Saved frames and optical flow images for clip: 053_2
# Saved frames and optical flow images for clip: 053_3
# Saved frames and optical flow images for clip: 053_4
# Saved frames and optical flow images for clip: 053_5
# Saved frames and optical flow images for clip: 053_6
# Saved frames and optical flow images for clip: 053_7
# Saved frames and optical flow images for clip: 053_8
# Saved frames and optical flow images for clip: 053_9
# Saved frames and optical flow images for clip: 053_10
# Saved frames and optical flow images for clip: 053_11
# Saved frames and optical flow images for clip: 053_12
# Saved frames and optical flow images for clip: 053_13
# Saved frames and optical flow images for clip: 053_14
# Saved frames and optical flow images for clip: 053_0
# Saved frames and optical flow images for clip: 053_1
# Saved frames and optical flow images for clip: 053_2
# Saved frames and optical flow images for clip: 053_3
# Saved frames and optical flow images for clip: 053_4
# Saved frames and optical flow images for clip: 053_5
# Saved frames and optical flow images for clip: 053_6
# Saved frames and optical flow images for clip: 053_7
# Saved frames and optical flow images for clip: 053_8
# Saved frames and optical flow images for clip: 053_9
# Saved frames and optical flow images for clip: 053_10
# Saved frames and optical flow images for clip: 053_11
# Saved frames and optical flow images for clip: 053_12
# Saved frames and optical flow images for clip: 085_0
# Saved frames and optical flow images for clip: 085_1
# Saved frames and optical flow images for clip: 085_2
# Saved frames and optical flow images for clip: 085_0
# Saved frames and optical flow images for clip: 028_0
# Saved frames and optical flow images for clip: 028_1
# Saved frames and optical flow images for clip: 028_2
# Saved frames and optical flow images for clip: 028_3
# Saved frames and optical flow images for clip: 028_4
# Saved frames and optical flow images for clip: 028_5
# Saved frames and optical flow images for clip: 028_6
# Saved frames and optical flow images for clip: 028_0
# Saved frames and optical flow images for clip: 028_1
# Saved frames and optical flow images for clip: 028_2
# Saved frames and optical flow images for clip: 028_3
# Saved frames and optical flow images for clip: 028_4
# Saved frames and optical flow images for clip: 099_0
# Saved frames and optical flow images for clip: 099_1
# Saved frames and optical flow images for clip: 099_2
# Saved frames and optical flow images for clip: 099_3
# Saved frames and optical flow images for clip: 099_4
# Saved frames and optical flow images for clip: 099_5
# Saved frames and optical flow images for clip: 099_6
# Saved frames and optical flow images for clip: 099_7
# Saved frames and optical flow images for clip: 099_8
# Saved frames and optical flow images for clip: 099_9
# Saved frames and optical flow images for clip: 099_10
# Saved frames and optical flow images for clip: 099_11
# Saved frames and optical flow images for clip: 099_12
# Saved frames and optical flow images for clip: 099_13
# Saved frames and optical flow images for clip: 099_0
# Saved frames and optical flow images for clip: 099_1
# Saved frames and optical flow images for clip: 099_2
# Saved frames and optical flow images for clip: 099_3
# Saved frames and optical flow images for clip: 099_4
# Saved frames and optical flow images for clip: 099_5
# Saved frames and optical flow images for clip: 099_6
# Saved frames and optical flow images for clip: 099_7
# Saved frames and optical flow images for clip: 099_8
# Saved frames and optical flow images for clip: 099_9
# Saved frames and optical flow images for clip: 099_10
# Saved frames and optical flow images for clip: 099_11
# Saved frames and optical flow images for clip: 041_0
# Saved frames and optical flow images for clip: 041_1
# Saved frames and optical flow images for clip: 041_2
# Saved frames and optical flow images for clip: 041_0
# Saved frames and optical flow images for clip: 065_0
# Saved frames and optical flow images for clip: 065_1
# Saved frames and optical flow images for clip: 065_2
# Saved frames and optical flow images for clip: 065_3
# Saved frames and optical flow images for clip: 065_4
# Saved frames and optical flow images for clip: 065_5
# Saved frames and optical flow images for clip: 065_6
# Saved frames and optical flow images for clip: 065_7
# Saved frames and optical flow images for clip: 065_8
# Saved frames and optical flow images for clip: 065_9
# Saved frames and optical flow images for clip: 065_10
# Saved frames and optical flow images for clip: 065_11
# Saved frames and optical flow images for clip: 065_12
# Saved frames and optical flow images for clip: 065_13
# Saved frames and optical flow images for clip: 065_14
# Saved frames and optical flow images for clip: 065_15
# Saved frames and optical flow images for clip: 065_16
# Saved frames and optical flow images for clip: 065_17
# Saved frames and optical flow images for clip: 065_18
# Saved frames and optical flow images for clip: 065_19
# Saved frames and optical flow images for clip: 065_20
# Saved frames and optical flow images for clip: 065_21
# Saved frames and optical flow images for clip: 065_22
# Saved frames and optical flow images for clip: 065_23
# Saved frames and optical flow images for clip: 065_24
# Saved frames and optical flow images for clip: 065_25
# Saved frames and optical flow images for clip: 065_26
# Saved frames and optical flow images for clip: 065_27
# Saved frames and optical flow images for clip: 065_28
# Saved frames and optical flow images for clip: 065_29
# Saved frames and optical flow images for clip: 065_0
# Saved frames and optical flow images for clip: 065_1
# Saved frames and optical flow images for clip: 065_2
# Saved frames and optical flow images for clip: 065_3
# Saved frames and optical flow images for clip: 065_4
# Saved frames and optical flow images for clip: 065_5
# Saved frames and optical flow images for clip: 065_6
# Saved frames and optical flow images for clip: 065_7
# Saved frames and optical flow images for clip: 065_8
# Saved frames and optical flow images for clip: 065_9
# Saved frames and optical flow images for clip: 065_10
# Saved frames and optical flow images for clip: 065_11
# Saved frames and optical flow images for clip: 065_12
# Saved frames and optical flow images for clip: 065_13
# Saved frames and optical flow images for clip: 065_14
# Saved frames and optical flow images for clip: 065_15
# Saved frames and optical flow images for clip: 065_16
# Saved frames and optical flow images for clip: 065_17
# Saved frames and optical flow images for clip: 065_18
# Saved frames and optical flow images for clip: 065_19
# Saved frames and optical flow images for clip: 065_20
# Saved frames and optical flow images for clip: 065_21
# Saved frames and optical flow images for clip: 065_22
# Saved frames and optical flow images for clip: 065_23
# Saved frames and optical flow images for clip: 065_24
# Saved frames and optical flow images for clip: 065_25
# Saved frames and optical flow images for clip: 065_26
# Saved frames and optical flow images for clip: 065_27
# Saved frames and optical flow images for clip: 074_0
# Saved frames and optical flow images for clip: 074_1
# Saved frames and optical flow images for clip: 074_2
# Saved frames and optical flow images for clip: 074_3
# Saved frames and optical flow images for clip: 074_4
# Saved frames and optical flow images for clip: 074_5
# Saved frames and optical flow images for clip: 074_6
# Saved frames and optical flow images for clip: 074_7
# Saved frames and optical flow images for clip: 074_8
# Saved frames and optical flow images for clip: 074_9
# Saved frames and optical flow images for clip: 074_10
# Saved frames and optical flow images for clip: 074_0
# ...
# Saved frames and optical flow images for clip: 021_4
# Saved frames and optical flow images for clip: 021_5
# Saved frames and optical flow images for clip: 021_6
# Saved frames and optical flow images for clip: 021_7
# Saved frames and optical flow images for clip: 021_8
# Saved frames and optical flow images for clip: 021_9
# Saved frames and optical flow images for clip: 021_10
# Saved frames and optical flow images for clip: 021_11
# Saved frames and optical flow images for clip: 021_12
# Saved frames and optical flow images for clip: 021_13
# Saved frames and optical flow images for clip: 021_14
# Saved frames and optical flow images for clip: 021_15
# Saved frames and optical flow images for clip: 021_16
# Saved frames and optical flow images for clip: 021_17
# Saved frames and optical flow images for clip: 021_18
# Saved frames and optical flow images for clip: 021_19
# Saved frames and optical flow images for clip: 021_20
# Saved frames and optical flow images for clip: 021_21
# Saved frames and optical flow images for clip: 021_22
# Saved frames and optical flow images for clip: 021_23
# Saved frames and optical flow images for clip: 021_24
# Saved frames and optical flow images for clip: 021_25
# Saved frames and optical flow images for clip: 021_26
# Saved frames and optical flow images for clip: 021_27
# Saved frames and optical flow images for clip: 021_28
# Saved frames and optical flow images for clip: 021_29
# Saved frames and optical flow images for clip: 075_0
# Saved frames and optical flow images for clip: 044_0
# Saved frames and optical flow images for clip: 044_1
# Saved frames and optical flow images for clip: 044_2
# Saved frames and optical flow images for clip: 044_3
# Saved frames and optical flow images for clip: 044_4
# Saved frames and optical flow images for clip: 044_0
# Saved frames and optical flow images for clip: 044_1
# Saved frames and optical flow images for clip: 044_2
# Saved frames and optical flow images for clip: 064_0
# Saved frames and optical flow images for clip: 064_1
# Saved frames and optical flow images for clip: 064_2
# Saved frames and optical flow images for clip: 064_3
# Saved frames and optical flow images for clip: 064_0
# Saved frames and optical flow images for clip: 064_1
# Saved frames and optical flow images for clip: 020_0
# Saved frames and optical flow images for clip: 020_1
# Saved frames and optical flow images for clip: 020_2
# Saved frames and optical flow images for clip: 020_3
# Saved frames and optical flow images for clip: 020_4
# Saved frames and optical flow images for clip: 020_5
# Saved frames and optical flow images for clip: 020_6
# Saved frames and optical flow images for clip: 020_7
# Saved frames and optical flow images for clip: 020_8
# Saved frames and optical flow images for clip: 020_9
# Saved frames and optical flow images for clip: 020_10
# Saved frames and optical flow images for clip: 020_11
# Saved frames and optical flow images for clip: 020_12
# Saved frames and optical flow images for clip: 020_13
# Saved frames and optical flow images for clip: 020_14
# Saved frames and optical flow images for clip: 020_15
# Saved frames and optical flow images for clip: 020_16
# Saved frames and optical flow images for clip: 020_17
# Saved frames and optical flow images for clip: 020_18
# Saved frames and optical flow images for clip: 020_19
# Saved frames and optical flow images for clip: 020_20
# Saved frames and optical flow images for clip: 020_21
# Saved frames and optical flow images for clip: 020_22
# Saved frames and optical flow images for clip: 020_23
# Saved frames and optical flow images for clip: 020_24
# Saved frames and optical flow images for clip: 020_25
# Saved frames and optical flow images for clip: 020_26
# Saved frames and optical flow images for clip: 020_27
# Saved frames and optical flow images for clip: 020_28
# Saved frames and optical flow images for clip: 020_29
# Saved frames and optical flow images for clip: 020_0
# Saved frames and optical flow images for clip: 020_1
# Saved frames and optical flow images for clip: 020_2
# Saved frames and optical flow images for clip: 020_3
# Saved frames and optical flow images for clip: 020_4
# Saved frames and optical flow images for clip: 020_5
# Saved frames and optical flow images for clip: 020_6
# Saved frames and optical flow images for clip: 020_7
# Saved frames and optical flow images for clip: 020_8
# Saved frames and optical flow images for clip: 020_9
# Saved frames and optical flow images for clip: 020_10
# Saved frames and optical flow images for clip: 020_11
# Saved frames and optical flow images for clip: 020_12
# Saved frames and optical flow images for clip: 020_13
# Saved frames and optical flow images for clip: 020_14
# Saved frames and optical flow images for clip: 020_15
# Saved frames and optical flow images for clip: 020_16
# Saved frames and optical flow images for clip: 020_17
# Saved frames and optical flow images for clip: 020_18
# Saved frames and optical flow images for clip: 020_19
# Saved frames and optical flow images for clip: 020_20
# Saved frames and optical flow images for clip: 020_21
# Saved frames and optical flow images for clip: 020_22
# Saved frames and optical flow images for clip: 020_23
# Saved frames and optical flow images for clip: 020_24
# Saved frames and optical flow images for clip: 020_25
# Saved frames and optical flow images for clip: 020_26
# Saved frames and optical flow images for clip: 020_27
# Saved frames and optical flow images for clip: 061_0
# Saved frames and optical flow images for clip: 061_1
# Saved frames and optical flow images for clip: 061_2
# Saved frames and optical flow images for clip: 061_3
# Saved frames and optical flow images for clip: 061_4
# Saved frames and optical flow images for clip: 061_5
# Saved frames and optical flow images for clip: 061_6
# Saved frames and optical flow images for clip: 061_7
# Saved frames and optical flow images for clip: 061_8
# Saved frames and optical flow images for clip: 061_0
# Saved frames and optical flow images for clip: 061_1
# Saved frames and optical flow images for clip: 061_2
# Saved frames and optical flow images for clip: 061_3
# Saved frames and optical flow images for clip: 061_4
# Saved frames and optical flow images for clip: 061_5
# Saved frames and optical flow images for clip: 061_6
# Saved frames and optical flow images for clip: 047_0
# Saved frames and optical flow images for clip: 047_1
# Saved frames and optical flow images for clip: 047_2
# Saved frames and optical flow images for clip: 047_3
# Saved frames and optical flow images for clip: 047_4
# Saved frames and optical flow images for clip: 047_5
# Saved frames and optical flow images for clip: 047_6
# Saved frames and optical flow images for clip: 047_7
# Saved frames and optical flow images for clip: 047_8
# Saved frames and optical flow images for clip: 047_9
# Saved frames and optical flow images for clip: 047_10
# Saved frames and optical flow images for clip: 047_11
# Saved frames and optical flow images for clip: 047_0
# Saved frames and optical flow images for clip: 047_1
# Saved frames and optical flow images for clip: 047_2
# Saved frames and optical flow images for clip: 047_3
# Saved frames and optical flow images for clip: 047_4
# Saved frames and optical flow images for clip: 047_5
# Saved frames and optical flow images for clip: 047_6
# Saved frames and optical flow images for clip: 047_7
# Saved frames and optical flow images for clip: 047_8
# Saved frames and optical flow images for clip: 047_9
# Saved frames and optical flow images for clip: 016_0
# Saved frames and optical flow images for clip: 016_1
# Saved frames and optical flow images for clip: 016_2
# Saved frames and optical flow images for clip: 016_3
# Saved frames and optical flow images for clip: 016_4
# Saved frames and optical flow images for clip: 016_5
# Saved frames and optical flow images for clip: 016_6
# Saved frames and optical flow images for clip: 016_7
# Saved frames and optical flow images for clip: 016_8
# Saved frames and optical flow images for clip: 016_9
# Saved frames and optical flow images for clip: 016_10
# Saved frames and optical flow images for clip: 016_11
# Saved frames and optical flow images for clip: 016_12
# Saved frames and optical flow images for clip: 016_13
# Saved frames and optical flow images for clip: 016_0
# Saved frames and optical flow images for clip: 016_1
# Saved frames and optical flow images for clip: 016_2
# Saved frames and optical flow images for clip: 016_3
# Saved frames and optical flow images for clip: 016_4
# Saved frames and optical flow images for clip: 016_5
# Saved frames and optical flow images for clip: 016_6
# Saved frames and optical flow images for clip: 016_7
# Saved frames and optical flow images for clip: 016_8
# Saved frames and optical flow images for clip: 016_9
# Saved frames and optical flow images for clip: 016_10
# Saved frames and optical flow images for clip: 016_11
# Saved frames and optical flow images for clip: 068_0
# Saved frames and optical flow images for clip: 068_1
# Saved frames and optical flow images for clip: 068_2
# Saved frames and optical flow images for clip: 068_3
# Saved frames and optical flow images for clip: 068_4
# Saved frames and optical flow images for clip: 068_5
# Saved frames and optical flow images for clip: 068_6
# Saved frames and optical flow images for clip: 068_7
# Saved frames and optical flow images for clip: 068_8
# Saved frames and optical flow images for clip: 068_9
# Saved frames and optical flow images for clip: 068_10
# Saved frames and optical flow images for clip: 068_11
# Saved frames and optical flow images for clip: 068_12
# Saved frames and optical flow images for clip: 068_13
# Saved frames and optical flow images for clip: 068_14
# Saved frames and optical flow images for clip: 068_15
# Saved frames and optical flow images for clip: 068_16
# Saved frames and optical flow images for clip: 068_17
# Saved frames and optical flow images for clip: 068_18
# Saved frames and optical flow images for clip: 068_19
# Saved frames and optical flow images for clip: 068_20
# Saved frames and optical flow images for clip: 068_21
# Saved frames and optical flow images for clip: 068_22
# Saved frames and optical flow images for clip: 068_23
# Saved frames and optical flow images for clip: 068_24
# Saved frames and optical flow images for clip: 068_0
# Saved frames and optical flow images for clip: 068_1
# Saved frames and optical flow images for clip: 068_2
# Saved frames and optical flow images for clip: 068_3
# Saved frames and optical flow images for clip: 068_4
# Saved frames and optical flow images for clip: 068_5
# Saved frames and optical flow images for clip: 068_6
# Saved frames and optical flow images for clip: 068_7
# Saved frames and optical flow images for clip: 068_8
# Saved frames and optical flow images for clip: 068_9
# Saved frames and optical flow images for clip: 068_10
# Saved frames and optical flow images for clip: 068_11
# Saved frames and optical flow images for clip: 068_12
# Saved frames and optical flow images for clip: 068_13
# Saved frames and optical flow images for clip: 068_14
# Saved frames and optical flow images for clip: 068_15
# Saved frames and optical flow images for clip: 068_16
# Saved frames and optical flow images for clip: 068_17
# Saved frames and optical flow images for clip: 068_18
# Saved frames and optical flow images for clip: 068_19
# Saved frames and optical flow images for clip: 068_20
# Saved frames and optical flow images for clip: 068_21
# Saved frames and optical flow images for clip: 068_22
# Saved frames and optical flow images for clip: 098_0
# Saved frames and optical flow images for clip: 098_1
# Saved frames and optical flow images for clip: 098_2
# Saved frames and optical flow images for clip: 098_3
# Saved frames and optical flow images for clip: 098_4
# Saved frames and optical flow images for clip: 098_5
# Saved frames and optical flow images for clip: 098_6
# Saved frames and optical flow images for clip: 098_7
# Saved frames and optical flow images for clip: 098_8
# Saved frames and optical flow images for clip: 098_0
# Saved frames and optical flow images for clip: 098_1
# Saved frames and optical flow images for clip: 098_2
# Saved frames and optical flow images for clip: 098_3
# Saved frames and optical flow images for clip: 098_4
# Saved frames and optical flow images for clip: 098_5
# Saved frames and optical flow images for clip: 098_6
# Saved frames and optical flow images for clip: 087_0
# Saved frames and optical flow images for clip: 087_1
# Saved frames and optical flow images for clip: 087_2
# Saved frames and optical flow images for clip: 087_3
# Saved frames and optical flow images for clip: 087_4
# Saved frames and optical flow images for clip: 087_5
# Saved frames and optical flow images for clip: 087_6
# Saved frames and optical flow images for clip: 087_7
# Saved frames and optical flow images for clip: 087_8
# Saved frames and optical flow images for clip: 087_9
# Saved frames and optical flow images for clip: 087_10
# Saved frames and optical flow images for clip: 087_11
# Saved frames and optical flow images for clip: 087_12
# Saved frames and optical flow images for clip: 087_13
# Saved frames and optical flow images for clip: 087_14
# Saved frames and optical flow images for clip: 087_15
# Saved frames and optical flow images for clip: 087_16
# Saved frames and optical flow images for clip: 087_17
# Saved frames and optical flow images for clip: 087_18
# Saved frames and optical flow images for clip: 087_19
# Saved frames and optical flow images for clip: 087_20
# Saved frames and optical flow images for clip: 087_0
# Saved frames and optical flow images for clip: 087_1
# Saved frames and optical flow images for clip: 087_2
# Saved frames and optical flow images for clip: 087_3
# Saved frames and optical flow images for clip: 087_4
# Saved frames and optical flow images for clip: 087_5
# Saved frames and optical flow images for clip: 087_6
# Saved frames and optical flow images for clip: 087_7
# Saved frames and optical flow images for clip: 087_8
# Saved frames and optical flow images for clip: 087_9
# Saved frames and optical flow images for clip: 087_10
# Saved frames and optical flow images for clip: 087_11
# Saved frames and optical flow images for clip: 087_12
# Saved frames and optical flow images for clip: 087_13
# Saved frames and optical flow images for clip: 087_14
# Saved frames and optical flow images for clip: 087_15
# Saved frames and optical flow images for clip: 087_16
# Saved frames and optical flow images for clip: 087_17
# Saved frames and optical flow images for clip: 087_18
# Saved frames and optical flow images for clip: 071_0
# Saved frames and optical flow images for clip: 071_1
# Saved frames and optical flow images for clip: 071_2
# Saved frames and optical flow images for clip: 071_3
# Saved frames and optical flow images for clip: 071_4
# Saved frames and optical flow images for clip: 071_5
# Saved frames and optical flow images for clip: 071_6
# Saved frames and optical flow images for clip: 071_7
# Saved frames and optical flow images for clip: 071_8
# Saved frames and optical flow images for clip: 071_9
# Saved frames and optical flow images for clip: 071_10
# Saved frames and optical flow images for clip: 071_0
# Saved frames and optical flow images for clip: 071_1
# Saved frames and optical flow images for clip: 071_2
# Saved frames and optical flow images for clip: 071_3
# Saved frames and optical flow images for clip: 071_4
# Saved frames and optical flow images for clip: 071_5
# Saved frames and optical flow images for clip: 071_6
# Saved frames and optical flow images for clip: 071_7
# Saved frames and optical flow images for clip: 071_8
# Saved frames and optical flow images for clip: 026_0
# Saved frames and optical flow images for clip: 026_1
# Saved frames and optical flow images for clip: 026_2
# Saved frames and optical flow images for clip: 026_3
# Saved frames and optical flow images for clip: 026_4
# Saved frames and optical flow images for clip: 026_5
# Saved frames and optical flow images for clip: 026_6
# Saved frames and optical flow images for clip: 026_0
# Saved frames and optical flow images for clip: 026_1
# Saved frames and optical flow images for clip: 026_2
# Saved frames and optical flow images for clip: 026_3
# Saved frames and optical flow images for clip: 026_4
